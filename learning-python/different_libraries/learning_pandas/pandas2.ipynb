# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.Series(pd.date_range("20130101", periods=1000))
dates
# Out:
# 0     2013-01-01
# 1     2013-01-02
# 2     2013-01-03
# 3     2013-01-04
# 4     2013-01-05
#          ...
# 995   2015-09-23
# 996   2015-09-24
# 997   2015-09-25
# 998   2015-09-26
# 999   2015-09-27
# Length: 1000, dtype: datetime64[ns]

# %%
df = pd.DataFrame(np.random.randn(1000, 1), index=dates, columns=["A"])
df
# Out:
#                    A
# 2013-01-01  0.718051
# 2013-01-02 -0.966771
# 2013-01-03  0.321018
# 2013-01-04 -0.647316
# 2013-01-05 -2.054113
# ...              ...
# 2015-09-23 -1.017406
# 2015-09-24 -1.832446
# 2015-09-25  0.786780
# 2015-09-26 -0.840450
# 2015-09-27 -1.192688
#
# [1000 rows x 1 columns]

# %%
df.dtypes
# Out:
# A    float64
# dtype: object

# %%
df.describe()
# Out:
#                  A
# count  1000.000000
# mean      0.002251
# std       0.991463
# min      -2.894265
# 25%      -0.655920
# 50%      -0.046934
# 75%       0.689254
# max       3.619177

# %%
df2 = df * np.random.rand(1000, 1)

# %%
df2
# Out:
#                    A
# 2013-01-01  0.077609
# 2013-01-02 -0.069864
# 2013-01-03  0.281201
# 2013-01-04 -0.217214
# 2013-01-05 -0.929427
# ...              ...
# 2015-09-23 -0.199338
# 2015-09-24 -0.335280
# 2015-09-25  0.128192
# 2015-09-26 -0.411066
# 2015-09-27 -0.072936
#
# [1000 rows x 1 columns]

# %%
df2.describe()
# Out:
#                  A
# count  1000.000000
# mean     -0.009009
# std       0.577399
# min      -2.500411
# 25%      -0.262661
# 50%      -0.007735
# 75%       0.229624
# max       2.620952

# %%
import matplotlib.pyplot as plt
df.plot(title="Random Data over Time", figsize=(10, 6))
plt.show()

# %%
df2.plot(title="Random Data over Time", figsize=(10, 6))
plt.show()
