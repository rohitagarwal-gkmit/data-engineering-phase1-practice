# %%
import pandas as pd

# %%
df = pd.read_json('final_aggregated_data.json')
df
# Out:
#                      Tehran          Mzuzu          Cairo      Las Vegas  \
# total_temp    413566.400000  428298.900000  520416.400000  488831.000000
# count          24285.000000   24169.000000   24246.000000   24106.000000
# max_temp          57.500000      57.800000      60.600000      61.800000
# min_temp         -24.000000     -23.400000     -24.900000     -19.800000
# average_temp      17.029706      17.721002      21.464011      20.278395
# mean_temp         16.750000      17.200000      17.850000      21.000000
#
#                     Denver         Douala      Palembang     Charlotte  \
# total_temp    249262.50000  650067.600000  662516.500000  397047.70000
# count          24308.00000   24381.000000   24262.000000   24534.00000
# max_temp          51.20000      64.900000      67.300000      53.40000
# min_temp         -36.30000      -9.500000     -10.000000     -22.60000
# average_temp      10.25434      26.662877      27.306755      16.18357
# ...

# %%
pivot_df = df.transpose()
pivot_df
# Out:
#              total_temp    count  max_temp  min_temp  average_temp  mean_temp
# Tehran         413566.4  24285.0      57.5     -24.0     17.029706      16.75
# Mzuzu          428298.9  24169.0      57.8     -23.4     17.721002      17.20
# Cairo          520416.4  24246.0      60.6     -24.9     21.464011      17.85
# Las Vegas      488831.0  24106.0      61.8     -19.8     20.278395      21.00
# Denver         249262.5  24308.0      51.2     -36.3     10.254340       7.45
# ...                 ...      ...       ...       ...           ...        ...
# Rabat          417770.8  24158.0      60.5     -22.8     17.293269      18.85
# Gangtok        366745.7  24210.0      57.4     -25.6     15.148521      15.90
# Singapore      653825.9  24160.0      68.4     -14.5     27.062330      26.95
# Tamanrasset    525322.6  24251.0      59.2     -16.4     21.661894      21.40
# Edmonton       102698.3  24285.0      53.9     -36.8      4.228878       8.55
#
# [413 rows x 6 columns]
